# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import broadcast
from  pyspark.sql.types import *
from pyspark.sql.functions import *

spark = SparkSession.builder \
    .appName("JoinPractice") \
    .getOrCreate()

# %%
df_sales = spark.read \
    .format("csv") \
    .option("header", "True") \
    .option("inferSchema", "True") \
    .load("/Volumes/workspace/practice/practice-1/sales.csv")

df_product = spark.read \
    .format("csv") \
    .option("header", "True") \
    .option("inferSchema", "True") \
    .load("/Volumes/workspace/practice/practice-1/product.csv")

# %%
display(df_sales)
display(df_product)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>sales</th></tr></thead><tbody><tr><td>1</td><td>100</td></tr><tr><td>2</td><td>200</td></tr><tr><td>3</td><td>300</td></tr><tr><td>1</td><td>1000</td></tr><tr><td>2</td><td>200</td></tr><tr><td>3</td><td>300</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
joined_df = df_sales.join(
    df_product,
    "id",
    "inner"
)

joined_df.show()
# Out:
# +---+-----+----+
# | id|sales|name|
# +---+-----+----+
# |  1| 1000|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# |  1|  100|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# +---+-----+----+

# %%
df_sales.join(df_product, "id", "left").show()
# Out:
# +---+-----+----+
# | id|sales|name|
# +---+-----+----+
# |  1|  100|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# |  1| 1000|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# +---+-----+----+

# %%
df_sales.join(df_product, "id", "right").show()
# Out:
# +---+-----+----+
# | id|sales|name|
# +---+-----+----+
# |  1| 1000|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# |  4| NULL|  p4|
# |  5| NULL|  p5|
# |  6| NULL|  p6|
# |  7| NULL|  p7|
# |  8| NULL|  p8|
# |  9| NULL|  p9|
# | 10| NULL| p10|
# |  1|  100|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# +---+-----+----+

# %%
df_sales.join(df_product, "id", "outer").show()
# Out:
# +---+-----+----+
# | id|sales|name|
# +---+-----+----+
# |  5| NULL|  p5|
# | 10| NULL| p10|
# |  1| 1000|  p1|
# |  3|  300|  p3|
# |  2|  200|  p2|
# |  6| NULL|  p6|
# |  9| NULL|  p9|
# |  7| NULL|  p7|
# |  4| NULL|  p4|
# |  8| NULL|  p8|
# |  1|  100|  p1|
# |  3|  300|  p3|
# |  2|  200|  p2|
# +---+-----+----+

# %%
joined_df = df_sales.join(
    broadcast(df_product),
    "id",
    "inner"
)

joined_df.show()
# Out:
# +---+-----+----+
# | id|sales|name|
# +---+-----+----+
# |  1|  100|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# |  1| 1000|  p1|
# |  2|  200|  p2|
# |  3|  300|  p3|
# +---+-----+----+

# %%
from pyspark.sql.functions import col

df_product = df_product.withColumn("Quantity", col("id") * 10)

# %%
display(df_product)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>Quantity</th></tr></thead><tbody><tr><td>1</td><td>p1</td><td>10</td></tr><tr><td>2</td><td>p2</td><td>20</td></tr><tr><td>3</td><td>p3</td><td>30</td></tr><tr><td>4</td><td>p4</td><td>40</td></tr><tr><td>5</td><td>p5</td><td>50</td></tr><tr><td>6</td><td>p6</td><td>60</td></tr><tr><td>7</td><td>p7</td><td>70</td></tr><tr><td>8</td><td>p8</td><td>80</td></tr><tr><td>9</td><td>p9</td><td>90</td></tr><tr><td>10</td><td>p10</td><td>100</td></tr></tbody></table></div>
